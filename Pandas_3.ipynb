# %% [markdown]
# Write a Pandas program to filter the records from the world alcohol consumption dataset where the GDP per capita is above 10,000 and the wine servings are greater than 100. Retrieve the country, beer servings, spirit servings, and life expectancy for these filtered records.

# %%
import pandas as pd

df = pd.read_csv("dataset/World_Alcohol_Dataset - MAIN.csv")

# %%
df
# Out:
#                  country beer_servings spirit_servings wine_servings  \
# 0            Afghanistan             0               0             0
# 1                Albania            89             132            54
# 2                Algeria            25               0            14
# 3                 Angola           217              57            45
# 4    Antigua and Barbuda           102             128            45
# ..                   ...           ...             ...           ...
# 172            Venezuela           333             100             3
# 173              Vietnam           111               2             1
# 174                Yemen             6               0             0
# 175               Zambia            32              19             4
# 176             Zimbabwe            64              18             4
#
#      life_expentancy                region  gdp_per_capita
# 0               65.0  ASIA (EX. NEAR EAST)             700
# ...

# %%
df[df["wine_servings"].str.contains("\?")] #we can see the row with the "?" character.
# Out:
#     country beer_servings spirit_servings wine_servings  life_expentancy  \
# 10  Bahamas           122             176             ?             76.1
#
#                  region  gdp_per_capita
# 10  LATIN AMER. & CARIB           16700

# %%
df=df[df["wine_servings"]!="?"] #we dropped the row due the missing data on wine_servings

# %%
df[df["wine_servings"].str.contains("\?")] #we check again
# Out:
# Empty DataFrame
# Columns: [country, beer_servings, spirit_servings, wine_servings, life_expentancy, region, gdp_per_capita]
# Index: []

# %%
df["wine_servings"]=df["wine_servings"].astype(int) #we cast the int type on "wine_servings"

# %%
df.dtypes
# Out:
# country             object
# beer_servings       object
# spirit_servings     object
# wine_servings        int64
# life_expentancy    float64
# region              object
# gdp_per_capita       int64
# dtype: object

# %%
filtered_df=df[(df["gdp_per_capita"]>10000)&(df["wine_servings"]>100)] #we initialize another df to filter the requested infos

filtered_df[["country","beer_servings","spirit_servings","life_expentancy"]] #we visualize only the requested columns
# Out:
#             country beer_servings spirit_servings  life_expentancy
# 5         Argentina           193              25             76.3
# 7         Australia           261              72             82.8
# 8           Austria           279              75             81.5
# 15          Belgium           295              84             81.1
# 40          Croatia           230              87             78.0
# 42           Cyprus           192             154             85.0
# 43          Czechia           361             170             78.8
# 44          Denmark           224               ?             86.0
# 57           France           127             151             82.4
# 61          Germany           346             117             81.0
# 63           Greece           133             112             81.0
# 71          Hungary           234             215             75.8
# 77          Ireland           313             118             81.4
# ...
