# %%
import pandas as pd

# %%
df=pd.read_csv("dataset/World_Alcohol_Dataset - MAIN.csv")

# %% [markdown]
# Write a Pandas program to filter the records from the world alcohol consumption dataset where the beer servings are greater than 200 lt and the life expectancy is above 70 years.

# %%
df.dtypes
# Out:
# country             object
# beer_servings       object
# spirit_servings     object
# wine_servings       object
# life_expentancy    float64
# region              object
# gdp_per_capita       int64
# dtype: object

# %%
df["beer_servings"].astype(int)
#can not cast "int" type to df["beer_servings"] because there is/are character/s with "?" string.
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 df["beer_servings"].astype(int)
#       2 #can not cast "int" type to df["beer_servings"] because there is/are character/s with "?" string.
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/generic.py:6324, in NDFrame.astype(self, dtype, copy, errors)
#    6317     results = [
#    6318         self.iloc[:, i].astype(dtype, copy=copy)
#    6319         for i in range(len(self.columns))
#    6320     ]
#    6322 else:
#    6323     # else, only a single dtype is given
# -> 6324     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6325     return self._constructor(new_data).__finalize__(self, method="astype")
#    6327 # GH 33113: handle empty frame or series
#
# ...

# %%
df[df["beer_servings"].str.contains("\?")] 
#now we can see the row with the "?" character.
# Out:
#       country beer_servings spirit_servings wine_servings  life_expentancy  \
# 96  Macedonia             ?              27            86             75.7
#
#             region  gdp_per_capita
# 96  EASTERN EUROPE            6700

# %%
df = df[df["beer_servings"]!= "?"] #we dropped the row due the missing data on beer_servings

# %%
df[df["beer_servings"].str.contains("\?")] #we do another check
# Out:
# Empty DataFrame
# Columns: [country, beer_servings, spirit_servings, wine_servings, life_expentancy, region, gdp_per_capita]
# Index: []

# %%
df["beer_servings"]=df["beer_servings"].astype(int)

# %%
df.dtypes # beer_servings is now int type
# Out:
# country             object
# beer_servings        int64
# spirit_servings     object
# wine_servings       object
# life_expentancy    float64
# region              object
# gdp_per_capita       int64
# dtype: object

# %%
filtered_df= df[(df["beer_servings"]>200) & (df["life_expentancy"]>70)] #we initialize another df to filter the requested infos

filtered_df
# Out:
#             country  beer_servings spirit_servings wine_servings  \
# 7         Australia            261              72           212
# 8           Austria            279              75           191
# 15          Belgium            295              84           212
# 16           Belize            263             114             8
# 22           Brazil            245             145            16
# 24         Bulgaria            231             252            94
# 30           Canada            240             122           100
# 40          Croatia            230              87           254
# 43          Czechia            361             170           134
# 44          Denmark            224               ?           278
# 53          Estonia            224             194            59
# 56          Finland            263             133            97
# 61          Germany            346             117           175
# ...
